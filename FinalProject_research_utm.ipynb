# %%
import pandas as pd
# %store -r df

# %%
# Out:
# (49708, 19)
# (45085, 19)

# %%
cols = ['session_id', 'client_id', 'visit_date', 'visit_time', 'visit_number', 'utm_source', 'utm_medium', 'utm_campaign', 'utm_adcontent', 'utm_keyword', 'device_category', 'device_os',
 'device_brand', 'device_model', 'device_screen_resolution', 'device_browser', 'geo_country', 'geo_city', 'target_event']
cols_utms = [ 'utm_source', 'utm_medium', 'utm_campaign', 'utm_adcontent', 'utm_keyword', 'target_event']
cols_device = ['device_os', 'device_brand', 'device_model', 'device_screen_resolution', 'device_browser']

from_adsence = ['QxAxdyPLuQMEcrdZWdWb', 'MvfHsxITijuriZxsqZqt', 'ISrKoXQCxqqYvAZICvjs', 'IZEXUFLARCUMynmHNBGo', 'PlbkrSYoHuZBWfYjYnfw',
                'gVRrcxiDQubJiljoTbGm']

is_organic = ['organic', 'referral', '(none)']

def view_occupancy(df):
    length = len(df)
    dic = dict()
    for col in df.columns:
        percent_filled = (length-df[col].isna().sum())/length
        dic[col] = percent_filled

    dic = sorted(dic.items(), key=lambda x: x[1], reverse=True)
    for k, v in dic:
        print('{}: {:.3f}%, {}'.format(k, v*100, df[k].isna().sum()))

# %%
df_utm = df[cols_utms].copy()
print(df_utm.shape)
view_occupancy(df_utm)
# Out:
# (1781974, 6)
# utm_medium: 100.000%, 0
# target_event: 100.000%, 0
# utm_source: 99.995%, 81
# utm_campaign: 88.643%, 202378
# utm_adcontent: 82.450%, 312744
# utm_keyword: 40.802%, 1054898

# %%
df_utm['utm_keyword'].isna().sum()
# Out:
# 1054898

# %%
df_utm = df_utm[~df_utm['utm_keyword'].isna()]
print(df_utm.shape)
df_utm.head(15)
# Out:
# (727076, 6)
#               utm_source utm_medium          utm_campaign  \
# 0   ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 1   MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
# 2   ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 6   TxKUcPpthBDPieTGmVhx        cpc  FTjNLDyTrXaWYgZymFkV
# 8   ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 13  gVRrcxiDQubJiljoTbGm   referral  LTuZkdKfxRGVceoWkVyg
# 16  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 18  ZpYIoDJMcFzVoPFsHGJL     banner  gecBYcKZCPMcVYdSSzKP
# 19  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 27  BHcvLfOaCWvWTykYqHVe        cpc                  <NA>
# 28  fDLlAcSmythWSCVMvqvL     (none)  LTuZkdKfxRGVceoWkVyg
# 31  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 36  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 37  kjsLglQLzykiRbcDiGcD        cpc  LwJZxKuWmvOhPsaCeRjG
# 38  kjsLglQLzykiRbcDiGcD        cpc  LwJZxKuWmvOhPsaCeRjG
#
# ...

# %%
df.utm_medium.value_counts(dropna=True)
# Out:
# banner               540289
# cpc                  408734
# (none)               287421
# cpm                  232270
# referral             144943
# organic               57047
# email                 28680
# push                  28548
# stories               10598
# cpv                    7928
# blogger_channel        7892
# smartbanner            6680
# blogger_stories        4261
# tg                     3971
# cpa                    3397
# post                   2281
# outlook                1288
# smm                    1281
# app                    1222
# clicks                  949
# blogger_header          762
# (not set)               432
# info_text               337
# sms                     210
# landing                 146
# partner                  96
# link                     53
# cbaafe                   43
# CPM                      39
# yandex_cpc               32
# vk_smm                   25
# static                   18
# google_cpc               15
# ...

# %%
df_grouped = df[['session_id', 'target_event']].groupby(['session_id', 'target_event']).agg("count").sort_values(by='target_event', ascending=False)
df_grouped
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_session_id = df[df['session_id'].duplicated()][['session_id', 'target_event']]
df_session_id.head(50)
# Out:
#                                      session_id  target_event
# 70    9055768928391199041.1623652678.1623652678             1
# 75    9055789093275396095.1636395007.1636395007             1
# 79    9055794766915104430.1624305327.1624305327             1
# 131   9056028189803556573.1630154471.1630154471             1
# 140   9056093322981390023.1628944098.1628944098             1
# 146   9056100040321437002.1640140105.1640140105             1
# 156   9056158125457201967.1638193974.1638193974             1
# 252   9056607924483613657.1624597468.1624597468             1
# 271   9056682094274849216.1625598516.1625598516             1
# 287   9056738860855987966.1623985736.1623985736             1
# 289   9056738860855987966.1624004393.1624004393             1
# 310   9056841918600823954.1628554390.1628554390             1
# 314   9056845320208664215.1622296993.1622296993             1
# 408   9057296532308149869.1637533303.1637533303             1
# ...

# %%
df[df['session_id']=='9055794766915104430.1624305327.1624305327']
# Out:
#                                    session_id              client_id  \
# 78  9055794766915104430.1624305327.1624305327  2108466524.1624305326
# 79  9055794766915104430.1624305327.1624305327  2108466524.1624305326
#
#     visit_date visit_time  visit_number            utm_source utm_medium  \
# 78  2021-06-21   22:00:00             1  BHcvLfOaCWvWTykYqHVe        cpc
# 79  2021-06-21   22:00:00             1  BHcvLfOaCWvWTykYqHVe        cpc
#
#    utm_campaign utm_adcontent utm_keyword device_category device_os  \
# 78         <NA>          <NA>        <NA>         desktop      <NA>
# 79         <NA>          <NA>        <NA>         desktop      <NA>
#
#    device_brand device_model device_screen_resolution device_browser  \
# 78         <NA>         <NA>                 834x1112         Safari
# 79         <NA>         <NA>                 834x1112         Safari
#
#    geo_country    geo_city  target_event
# 78      Russia  Domodedovo             0
# ...
